# %% [markdown]
# The goal of this project is to see which features have the highest correlation with the gross income of a movie.
# <br>
# <br>
# From briefly looking at the data, I'd say that budget has the highest correlation with the gross income.

# %%
# Importing packages

import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib.pyplot import figure
matplotlib.rcParams['figure.figsize'] = (12,8)
plt.style.use('Solarize_Light2')

# %%
df = pd.read_csv(r'C:\Users\Sara\Desktop\Work\Portfolio Projects\Python Correlation Project (Movies Dataset)\movies.csv')
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %% [markdown]
# ## Data Cleaning
# First we're going to check if there are any missing values in our dataset.

# %%
df.isnull().sum()
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
df.shape
# Out:
# (7668, 15)

# %%
df.isnull().sum().sum()
# Out:
# 2473

# %%
# We can see that the total number of missing values in our dataset is 2473,
# which means that if we drop all of them we're still going to have around 71% 
# of the data to work with

df = df.dropna()

# %%
df.isnull().sum()
# Out:
# name        0
# rating      0
# genre       0
# year        0
# released    0
# score       0
# votes       0
# director    0
# writer      0
# star        0
# country     0
# budget      0
# gross       0
# company     0
# runtime     0
# dtype: int64

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')

# %%
df.head(10)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
# 5                                 Friday the 13th      R     Horror  1980
# 6                              The Blues Brothers      R     Action  1980
# 7                                     Raging Bull      R  Biography  1980
# 8                                     Superman II     PG     Action  1980
# 9                                 The Long Riders      R  Biography  1980
#
#                             released  score      votes            director  \
# 0      June 13, 1980 (United States)    8.4   927000.0     Stanley Kubrick
# ...

# %% [markdown]
# <br>
# <br>
# Just from skimming through the data we can see that in some cases the year in the 'year' column and the year in the 'released' column don't match. To fix that, we're going to pull the year from the 'released' column into a new one and drop the 'year' column.
# <br>

# %%
df[['month_day', 'year_country']] = df['released'].str.split(',',2, expand=True)
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
df['year_country'] = df['year_country'].str.strip(' ')
df['year_correct'] = df['year_country'].astype(str).str[:4]
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
df = df.drop(columns=['year', 'month_day', 'year_country'])
df.head()
# Out:
#                                              name rating      genre  \
# 0                                     The Shining      R      Drama
# 1                                 The Blue Lagoon      R  Adventure
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action
# 3                                       Airplane!     PG     Comedy
# 4                                      Caddyshack      R     Comedy
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000
# ...

# %% [markdown]
# Dropping all the duplicates, if there're any.

# %%
df.drop_duplicates()
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
# ...

# %% [markdown]
# ## EDA/Correlation

# %% [markdown]
# Now we're going to take a look at the outliers in the 'gross' column.

# %%
df.boxplot(column=['gross'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# <br>
# <br>
# Order the data by the gross revenue.

# %%
df.sort_values(by='gross', ascending=False)
# Out:
#                                             name     rating   genre  \
# 5445                                      Avatar      PG-13  Action
# 7445                           Avengers: Endgame      PG-13  Action
# 3045                                     Titanic      PG-13   Drama
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action
# 7244                      Avengers: Infinity War      PG-13  Action
# ...                                          ...        ...     ...
# 5640                                 Tanner Hall          R   Drama
# 2434                  Philadelphia Experiment II      PG-13  Action
# 3681                                Ginger Snaps  Not Rated   Drama
# 272                                     Parasite          R  Horror
# 3203                                  Trojan War      PG-13  Comedy
#
#                                released  score      votes  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0
# ...

# %% [markdown]
# <br>
# <br>
# Correlation between budget and gross earnings.

# %%
plt.scatter(x='gross', y='budget', data=df)
plt.xlabel('gross')
plt.ylabel('budget')
plt.title('Budget vs Gross Correlation')
plt.show()

# %%
sns.regplot(data=df, x='gross', y='budget', line_kws={'color':'red'})
plt.show()

# %% [markdown]
# From looking at the regression line we can conclude that there is a positive correlation between gross earnings and budget.
# <br>
# <br>
# Let's take a look at the numbers now.

# %% [markdown]
# ### Correlation Between Numerical Features

# %%
df.corr()
# Out:
#             score     votes    budget     gross   runtime
# score    1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.414068  0.352303  0.318695  0.275796  1.000000

# %%
correlation_matrix = df.corr()

# %%
sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matrix For Numeric Features')
plt.xlabel('Numeric Features')
plt.ylabel('Numeric Features')

plt.show()

# %% [markdown]
# ### Correlation Betweet Categorical Features
# In order to assess the correlation between gross earnings and categorical features we're going to have to 'transform' each categorical feature into a numeric by assigning a different number to each unique value.

# %%
df.head()
# Out:
#                                              name rating      genre  \
# 0                                     The Shining      R      Drama
# 1                                 The Blue Lagoon      R  Adventure
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action
# 3                                       Airplane!     PG     Comedy
# 4                                      Caddyshack      R     Comedy
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000
# ...

# %%
df_numerized = df.copy()

# %%
for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
        
df_numerized.head()
# Out:
#    name  rating  genre  released  score      votes  director  writer  star  \
# 0  4692       6      6      1304    8.4   927000.0      1795    2832   699
# 1  3929       6      1      1127    5.8    65000.0      1578    1158   214
# 2  3641       4      0      1359    8.7  1200000.0       757    1818  1157
# 3   204       4      4      1127    7.7   221000.0       889    1413  1474
# 4   732       6      4      1170    7.3   108000.0       719     351   271
#
#    country    budget      gross  company  runtime  year_correct
# 0       46  19000000   46998772     1426    146.0             0
# 1       47   4500000   58853106      452    104.0             0
# 2       47  18000000  538375067      945    124.0             0
# 3       47   3500000   83453539     1108     88.0             0
# 4       47   6000000   39846344     1083     98.0             0

# %%
correlation_matrix = df_numerized.corr()
correlation_matrix
# Out:
#                   name    rating     genre  released     score     votes  \
# name          1.000000 -0.029234  0.010996 -0.006152  0.014450  0.012615
# rating       -0.029234  1.000000  0.147796  0.018083  0.065983  0.006031
# genre         0.010996  0.147796  1.000000  0.022142  0.035106 -0.135990
# released     -0.006152  0.018083  0.022142  1.000000  0.045874  0.028833
# score         0.014450  0.065983  0.035106  0.045874  1.000000  0.474256
# votes         0.012615  0.006031 -0.135990  0.028833  0.474256  1.000000
# director      0.015246  0.014656 -0.008553  0.002308  0.005413 -0.010376
# writer        0.012880 -0.003149  0.017578  0.008072  0.012843 -0.005316
# star         -0.006882  0.009196  0.003341  0.015706  0.007296 -0.017638
# country      -0.025490  0.008230 -0.009164 -0.017228 -0.043051  0.041551
# budget        0.023392 -0.203946 -0.368523  0.019952  0.072001  0.439675
# gross         0.005639 -0.181906 -0.244101  0.008501  0.222556  0.614751
# ...

# %%
sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matrix For Movie Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')

plt.show()

# %%
df_numerized.corr()
# Out:
#                   name    rating     genre  released     score     votes  \
# name          1.000000 -0.029234  0.010996 -0.006152  0.014450  0.012615
# rating       -0.029234  1.000000  0.147796  0.018083  0.065983  0.006031
# genre         0.010996  0.147796  1.000000  0.022142  0.035106 -0.135990
# released     -0.006152  0.018083  0.022142  1.000000  0.045874  0.028833
# score         0.014450  0.065983  0.035106  0.045874  1.000000  0.474256
# votes         0.012615  0.006031 -0.135990  0.028833  0.474256  1.000000
# director      0.015246  0.014656 -0.008553  0.002308  0.005413 -0.010376
# writer        0.012880 -0.003149  0.017578  0.008072  0.012843 -0.005316
# star         -0.006882  0.009196  0.003341  0.015706  0.007296 -0.017638
# country      -0.025490  0.008230 -0.009164 -0.017228 -0.043051  0.041551
# budget        0.023392 -0.203946 -0.368523  0.019952  0.072001  0.439675
# gross         0.005639 -0.181906 -0.244101  0.008501  0.222556  0.614751
# ...

# %% [markdown]
# <br>
# <br>
# We want to look at the features that are highly correlated to the gross earnings.

# %%
# Looking at the correlation of each pair of the features

corr_matrix_unstacked = correlation_matrix.unstack()
corr_matrix_unstacked
# Out:
# name          name            1.000000
#               rating         -0.029234
#               genre           0.010996
#               released       -0.006152
#               score           0.014450
#                                 ...
# year_correct  budget          0.314628
#               gross           0.264334
#               company        -0.022510
#               runtime         0.073115
#               year_correct    1.000000
# Length: 225, dtype: float64

# %%
# Filtering down to those with correlation higher than 0.5

sorted_corr_matrix = corr_matrix_unstacked.sort_values(ascending=False)
high_corr = sorted_corr_matrix[sorted_corr_matrix > 0.5]
high_corr
# Out:
# name          name            1.000000
# rating        rating          1.000000
# runtime       runtime         1.000000
# company       company         1.000000
# gross         gross           1.000000
# budget        budget          1.000000
# country       country         1.000000
# star          star            1.000000
# director      director        1.000000
# votes         votes           1.000000
# score         score           1.000000
# released      released        1.000000
# genre         genre           1.000000
# writer        writer          1.000000
# year_correct  year_correct    1.000000
# gross         budget          0.740247
# budget        gross           0.740247
# votes         gross           0.614751
# gross         votes           0.614751
# dtype: float64

# %% [markdown]
# We can see that the only feature, other than the budget, that has a high correlation to the gross earnings is the 'votes' feature.

# %%
plt.scatter(x='gross', y='votes', data=df)
plt.xlabel('gross')
plt.ylabel('votes')
plt.title('Votes vs Gross Correlation')
plt.show()

# %% [markdown]
# ## Top 10 companies by gross revenue

# %%
df.head()
# Out:
#                                              name rating      genre  \
# 0                                     The Shining      R      Drama
# 1                                 The Blue Lagoon      R  Adventure
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action
# 3                                       Airplane!     PG     Comedy
# 4                                      Caddyshack      R     Comedy
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000
# ...

# %%
CompanyGrossSumSorted = df.groupby('company')[['gross']].sum().sort_values('gross', ascending=False)[:10]
CompanyGrossSumSorted
# Out:
#                              gross
# company
# Warner Bros.           54610959970
# Universal Pictures     51241105418
# Columbia Pictures      42356430218
# Paramount Pictures     40021704691
# Twentieth Century Fox  39542573303
# Walt Disney Pictures   35833650748
# New Line Cinema        19612851164
# Marvel Studios         15065592411
# DreamWorks Animation   11873612858
# Dreamworks Pictures    11593807697
